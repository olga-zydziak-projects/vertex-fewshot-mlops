# %%
# %pip install -e "/home/jupyter/mlops-meta-learning/fsl-projekt[dev,pipelines]"

# %%
# !cd /home/jupyter/mlops-meta-learning/fsl-projekt && /home/jupyter/envs/fsl/bin/python -m pytest -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.19, pytest-9.1.1, pluggy-1.6.0 -- /home/jupyter/envs/fsl/bin/python
# cachedir: .pytest_cache
# rootdir: /home/jupyter/mlops-meta-learning/fsl-projekt
# configfile: pyproject.toml
# plugins: anyio-4.14.1
# collected 5 items
#
# tests/test_protonet.py::test_fast_adapt_perfect_on_separable_episode PASSED [ 20%]
# tests/test_protonet.py::test_conv4_output_shape PASSED                   [ 40%]
# tests/test_protonet.py::test_prototypes_are_per_class_means PASSED       [ 60%]
# tests/test_protonet.py::test_split_produces_correct_counts PASSED        [ 80%]
# tests/test_smoke.py::test_import PASSED                                  [100%]
#
# ============================== 5 passed in 5.34s ===============================

# %%
import sys
# !cd /home/jupyter/mlops-meta-learning/fsl-projekt && {sys.executable} scripts/train.py --project dark-data-discovery --train-iters 300
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ...

# %%
# !gcloud ai models list --region=us-central1 --project=dark-data-discovery \
  --filter='displayName=fsl-protonet-omniglot' --format='value(name)'
# Out:
# Using endpoint [https://us-central1-aiplatform.googleapis.com/]
# 8493947776650969088

# %%
# !gcloud ai models list-versions 8493947776650969088 --region=us-central1 --project=dark-data-discovery
# Out:
# ERROR: (gcloud.ai.models) Invalid choice: 'list-versions'.
# Maybe you meant:
#   gcloud ai model-garden
#   gcloud ai models
#   gcloud ai-platform models
#   gcloud ai-platform versions
#
# To search the help text of gcloud commands, run:
#   gcloud help -- SEARCH_TERMS

# %%
# !docker run --rm --gpus all --entrypoint python \
  us-central1-docker.pkg.dev/dark-data-discovery/fsl-images/train:candidate \
  -c "import torch; print('cuda available:', torch.cuda.is_available())"
# Out:
# /usr/local/lib/python3.10/site-packages/torch/cuda/__init__.py:187: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0
# cuda available: False
