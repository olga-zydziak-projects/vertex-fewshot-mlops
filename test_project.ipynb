# %%
# %pip install -e "/home/jupyter/mlops-meta-learning/fsl-projekt[dev,pipelines]"
# Out:
# Obtaining file:///home/jupyter/mlops-meta-learning/fsl-projekt
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: learn2learn in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from fsl-projekt==0.1.0) (0.2.0)
# Requirement already satisfied: google-cloud-storage in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from fsl-projekt==0.1.0) (3.12.0)
# Requirement already satisfied: google-cloud-aiplatform in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from fsl-projekt==0.1.0) (1.159.0)
# Requirement already satisfied: torch in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from fsl-projekt==0.1.0) (2.12.1)
# Requirement already satisfied: torchvision in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from fsl-projekt==0.1.0) (0.27.1)
# Requirement already satisfied: matplotlib in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from fsl-projekt==0.1.0) (3.10.9)
# Requirement already satisfied: pytest in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from fsl-projekt==0.1.0) (9.1.1)
# Requirement already satisfied: ruff in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from fsl-projekt==0.1.0) (0.15.20)
# Collecting kfp (from fsl-projekt==0.1.0)
#   Downloading kfp-2.16.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting google-cloud-pipeline-components (from fsl-projekt==0.1.0)
#   Downloading google_cloud_pipeline_components-2.22.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform->fsl-projekt==0.1.0) (2.31.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-aiplatform->fsl-projekt==0.1.0) (2.55.1)
# Requirement already satisfied: certifi>=2023.7.22 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-aiplatform->fsl-projekt==0.1.0) (2026.6.17)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-aiplatform->fsl-projekt==0.1.0) (1.28.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-aiplatform->fsl-projekt==0.1.0) (6.33.6)
# Requirement already satisfied: packaging>=14.3 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-aiplatform->fsl-projekt==0.1.0) (26.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-aiplatform->fsl-projekt==0.1.0) (3.42.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-aiplatform->fsl-projekt==0.1.0) (1.18.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.66.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-aiplatform->fsl-projekt==0.1.0) (2.10.0)
# Requirement already satisfied: pydantic<3 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-aiplatform->fsl-projekt==0.1.0) (2.13.4)
# Requirement already satisfied: typing_extensions in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-aiplatform->fsl-projekt==0.1.0) (4.15.0)
# Requirement already satisfied: docstring_parser<1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-aiplatform->fsl-projekt==0.1.0) (0.18.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform->fsl-projekt==0.1.0) (1.75.0)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform->fsl-projekt==0.1.0) (2.34.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.41.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform->fsl-projekt==0.1.0) (1.81.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.41.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform->fsl-projekt==0.1.0) (1.81.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (46.0.7)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (2.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pyopenssl>=20.0.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-auth[pyopenssl]<3.0.0,>=2.14.1->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (26.0.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform->fsl-projekt==0.1.0) (0.14.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.6.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-storage->fsl-projekt==0.1.0) (1.8.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (4.14.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (1.9.0)
# Requirement already satisfied: sniffio in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (3.18)
# Requirement already satisfied: httpcore==1.* in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform->fsl-projekt==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform->fsl-projekt==0.1.0) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform->fsl-projekt==0.1.0) (0.4.2)
# Requirement already satisfied: six>=1.5 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform->fsl-projekt==0.1.0) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform->fsl-projekt==0.1.0) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (2.0.0)
# Requirement already satisfied: pycparser in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (0.6.3)
# Requirement already satisfied: Jinja2<4,>=3.1.2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-cloud-pipeline-components->fsl-projekt==0.1.0) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from Jinja2<4,>=3.1.2->google-cloud-pipeline-components->fsl-projekt==0.1.0) (3.0.3)
# Collecting click>=8.1.8 (from kfp->fsl-projekt==0.1.0)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting click-option-group==0.5.7 (from kfp->fsl-projekt==0.1.0)
#   Downloading click_option_group-0.5.7-py3-none-any.whl.metadata (5.8 kB)
# Collecting kfp-pipeline-spec<3,>=2.16.0 (from kfp->fsl-projekt==0.1.0)
#   Downloading kfp_pipeline_spec-2.16.1-py3-none-any.whl.metadata (433 bytes)
# Collecting kfp-server-api<3,>=2.16.0 (from kfp->fsl-projekt==0.1.0)
#   Downloading kfp_server_api-2.16.1.tar.gz (63 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting kubernetes<31,>=8.0.0 (from kfp->fsl-projekt==0.1.0)
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting PyYAML<7,>=5.3 (from kfp->fsl-projekt==0.1.0)
#   Downloading pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting requests-toolbelt<2,>=0.8.0 (from kfp->fsl-projekt==0.1.0)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting tabulate<1,>=0.8.6 (from kfp->fsl-projekt==0.1.0)
#   Downloading tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes<31,>=8.0.0->kfp->fsl-projekt==0.1.0)
#   Downloading websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting requests-oauthlib (from kubernetes<31,>=8.0.0->kfp->fsl-projekt==0.1.0)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes<31,>=8.0.0->kfp->fsl-projekt==0.1.0)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.15.4 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from learn2learn->fsl-projekt==0.1.0) (1.26.4)
# Requirement already satisfied: gym>=0.14.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from learn2learn->fsl-projekt==0.1.0) (0.26.2)
# Requirement already satisfied: scipy in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from learn2learn->fsl-projekt==0.1.0) (1.15.3)
# Requirement already satisfied: gsutil in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from learn2learn->fsl-projekt==0.1.0) (5.27)
# Requirement already satisfied: tqdm in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from learn2learn->fsl-projekt==0.1.0) (4.68.3)
# Requirement already satisfied: qpth>=0.0.15 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from learn2learn->fsl-projekt==0.1.0) (0.0.18)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gym>=0.14.0->learn2learn->fsl-projekt==0.1.0) (3.1.2)
# Requirement already satisfied: gym_notices>=0.0.4 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gym>=0.14.0->learn2learn->fsl-projekt==0.1.0) (0.1.0)
# Requirement already satisfied: cvxpy>=1.1.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from qpth>=0.0.15->learn2learn->fsl-projekt==0.1.0) (1.7.5)
# Requirement already satisfied: osqp>=1.0.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cvxpy>=1.1.0->qpth>=0.0.15->learn2learn->fsl-projekt==0.1.0) (1.1.3)
# Requirement already satisfied: clarabel>=0.5.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cvxpy>=1.1.0->qpth>=0.0.15->learn2learn->fsl-projekt==0.1.0) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cvxpy>=1.1.0->qpth>=0.0.15->learn2learn->fsl-projekt==0.1.0) (3.2.11)
# Requirement already satisfied: setuptools in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from osqp>=1.0.0->cvxpy>=1.1.0->qpth>=0.0.15->learn2learn->fsl-projekt==0.1.0) (79.0.1)
# Requirement already satisfied: joblib in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from osqp>=1.0.0->cvxpy>=1.1.0->qpth>=0.0.15->learn2learn->fsl-projekt==0.1.0) (1.5.3)
# Requirement already satisfied: filelock in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torch->fsl-projekt==0.1.0) (3.29.4)
# Requirement already satisfied: sympy>=1.13.3 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torch->fsl-projekt==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torch->fsl-projekt==0.1.0) (3.4.2)
# Requirement already satisfied: fsspec>=0.8.5 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torch->fsl-projekt==0.1.0) (2026.6.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->fsl-projekt==0.1.0) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torch->fsl-projekt==0.1.0) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torch->fsl-projekt==0.1.0) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torch->fsl-projekt==0.1.0) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torch->fsl-projekt==0.1.0) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torch->fsl-projekt==0.1.0) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torch->fsl-projekt==0.1.0) (3.4.5)
# Requirement already satisfied: triton==3.7.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torch->fsl-projekt==0.1.0) (3.7.1)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->fsl-projekt==0.1.0) (12.0.0.61)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->fsl-projekt==0.1.0) (12.6.3.3)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->fsl-projekt==0.1.0) (13.0.88)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->fsl-projekt==0.1.0) (12.0.4.66)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->fsl-projekt==0.1.0) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->fsl-projekt==0.1.0) (10.4.0.35)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->fsl-projekt==0.1.0) (1.15.1.6)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->fsl-projekt==0.1.0) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->fsl-projekt==0.1.0) (13.0.96)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->fsl-projekt==0.1.0) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from cuda-bindings<14,>=13.0.3->torch->fsl-projekt==0.1.0) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from sympy>=1.13.3->torch->fsl-projekt==0.1.0) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from torchvision->fsl-projekt==0.1.0) (12.2.0)
# Requirement already satisfied: argcomplete>=1.9.4 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gsutil->learn2learn->fsl-projekt==0.1.0) (3.6.3)
# Requirement already satisfied: crcmod>=1.7 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gsutil->learn2learn->fsl-projekt==0.1.0) (1.7)
# Requirement already satisfied: fasteners>=0.14.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gsutil->learn2learn->fsl-projekt==0.1.0) (0.20)
# Requirement already satisfied: gcs-oauth2-boto-plugin>=3.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gsutil->learn2learn->fsl-projekt==0.1.0) (3.1)
# Requirement already satisfied: google-apitools>=0.5.32 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gsutil->learn2learn->fsl-projekt==0.1.0) (0.5.35)
# Requirement already satisfied: httplib2==0.20.4 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gsutil->learn2learn->fsl-projekt==0.1.0) (0.20.4)
# Requirement already satisfied: google-reauth>=0.1.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gsutil->learn2learn->fsl-projekt==0.1.0) (0.1.1)
# Requirement already satisfied: monotonic>=1.4 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gsutil->learn2learn->fsl-projekt==0.1.0) (1.6)
# Requirement already satisfied: retry_decorator>=1.0.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gsutil->learn2learn->fsl-projekt==0.1.0) (1.1.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from httplib2==0.20.4->gsutil->learn2learn->fsl-projekt==0.1.0) (3.3.2)
# Requirement already satisfied: rsa==4.7.2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gcs-oauth2-boto-plugin>=3.0->gsutil->learn2learn->fsl-projekt==0.1.0) (4.7.2)
# Requirement already satisfied: boto>=2.29.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gcs-oauth2-boto-plugin>=3.0->gsutil->learn2learn->fsl-projekt==0.1.0) (2.49.0)
# Requirement already satisfied: oauth2client>=2.2.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from gcs-oauth2-boto-plugin>=3.0->gsutil->learn2learn->fsl-projekt==0.1.0) (4.1.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (3.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform->fsl-projekt==0.1.0) (1.24.2)
# Requirement already satisfied: pyu2f in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from google-reauth>=0.1.0->gsutil->learn2learn->fsl-projekt==0.1.0) (0.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from matplotlib->fsl-projekt==0.1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from matplotlib->fsl-projekt==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from matplotlib->fsl-projekt==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from matplotlib->fsl-projekt==0.1.0) (1.5.0)
# Requirement already satisfied: iniconfig>=1.0.1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from pytest->fsl-projekt==0.1.0) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from pytest->fsl-projekt==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from pytest->fsl-projekt==0.1.0) (2.20.0)
# Requirement already satisfied: tomli>=1 in /home/jupyter/envs/fsl/lib/python3.10/site-packages (from pytest->fsl-projekt==0.1.0) (2.4.1)
# Downloading google_cloud_pipeline_components-2.22.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.9 MB/s  0:00:00
# Downloading kfp-2.16.1-py3-none-any.whl (421 kB)
# Downloading click_option_group-0.5.7-py3-none-any.whl (11 kB)
# Downloading kfp_pipeline_spec-2.16.1-py3-none-any.whl (9.9 kB)
# Downloading kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 69.2 MB/s  0:00:00
# Downloading pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (770 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 kB 52.5 MB/s  0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading tabulate-0.10.0-py3-none-any.whl (39 kB)
# Downloading click-8.4.2-py3-none-any.whl (119 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: fsl-projekt, kfp-server-api
#   Building editable for fsl-projekt (pyproject.toml) ... done
#   Created wheel for fsl-projekt: filename=fsl_projekt-0.1.0-0.editable-py3-none-any.whl size=1427 sha256=b1eb04469f8cf51f7fde2653bd45cf2802be31b6ecc6c6ed01c3a671c4b0b9af
#   Stored in directory: /var/tmp/pip-ephem-wheel-cache-6iad0ack/wheels/a5/8d/db/09c9babf91f973f877caf4fc7085772ab8b63bd65a8f087244
#   Building wheel for kfp-server-api (pyproject.toml) ... done
#   Created wheel for kfp-server-api: filename=kfp_server_api-2.16.1-py3-none-any.whl size=115414 sha256=b327d3363a3ea4c9e41ae0788f5e93d488a6e804311bddb591333307345e9217
#   Stored in directory: /home/jupyter/.cache/pip/wheels/90/13/05/8c4d65ce63e5ce9e50abe31bcd377d65122205a2704c668284
# Successfully built fsl-projekt kfp-server-api
# Installing collected packages: websocket-client, tabulate, PyYAML, oauthlib, kfp-pipeline-spec, click, requests-toolbelt, requests-oauthlib, kfp-server-api, click-option-group, kubernetes, kfp, google-cloud-pipeline-components, fsl-projekt
#   Attempting uninstall: fsl-projekt━━━╸━━━━━ 12/14 [google-cloud-pipeline-components]
#     Found existing installation: fsl-projekt 0.1.090m━━━━━ 12/14 [google-cloud-pipeline-components]
#     Uninstalling fsl-projekt-0.1.0:╸━━━━━ 12/14 [google-cloud-pipeline-components]
#       Successfully uninstalled fsl-projekt-0.1.0m╺━━ 13/14 [fsl-projekt]e-components]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [fsl-projekt] [fsl-projekt]
# Successfully installed PyYAML-6.0.3 click-8.4.2 click-option-group-0.5.7 fsl-projekt-0.1.0 google-cloud-pipeline-components-2.22.0 kfp-2.16.1 kfp-pipeline-spec-2.16.1 kfp-server-api-2.16.1 kubernetes-30.1.0 oauthlib-3.3.1 requests-oauthlib-2.0.0 requests-toolbelt-1.0.0 tabulate-0.10.0 websocket-client-1.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !cd /home/jupyter/mlops-meta-learning/fsl-projekt && /home/jupyter/envs/fsl/bin/python -m pytest -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.19, pytest-9.1.1, pluggy-1.6.0 -- /home/jupyter/envs/fsl/bin/python
# cachedir: .pytest_cache
# rootdir: /home/jupyter/mlops-meta-learning/fsl-projekt
# configfile: pyproject.toml
# plugins: anyio-4.14.1
# collected 5 items
#
# tests/test_protonet.py::test_fast_adapt_perfect_on_separable_episode PASSED [ 20%]
# tests/test_protonet.py::test_conv4_output_shape PASSED                   [ 40%]
# tests/test_protonet.py::test_prototypes_are_per_class_means PASSED       [ 60%]
# tests/test_protonet.py::test_split_produces_correct_counts PASSED        [ 80%]
# tests/test_smoke.py::test_import PASSED                                  [100%]
#
# ============================== 5 passed in 5.34s ===============================

# %%
import sys
# !cd /home/jupyter/mlops-meta-learning/fsl-projekt && {sys.executable} scripts/train.py --project dark-data-discovery --train-iters 300
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/torch/cuda/__init__.py:187: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0
# Device: cpu
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.resourcemanager_v3 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.resourcemanager_v3 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.predict.instance_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.predict.instance_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.predict.params_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.predict.params_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.predict.prediction_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.predict.prediction_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.trainingjob.definition_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.trainingjob.definition_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.predict.instance_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.predict.instance_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.predict.params_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.predict.params_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.predict.prediction_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.predict.prediction_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/envs/fsl/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.trainingjob.definition_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.trainingjob.definition_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# Associating projects/815755318672/locations/us-central1/metadataStores/default/contexts/fsl-omniglot-protonet-protonet-5w5s-seed0-1783035079 to Experiment: fsl-omniglot-protonet
# Run started: protonet-5w5s-seed0-1783035079
# iter     1 | train loss 1.049 acc 0.720 | val acc 0.790 +/- 0.012
# iter    50 | train loss 0.379 acc 0.909 | val acc 0.937 +/- 0.006
# iter   100 | train loss 0.166 acc 0.957 | val acc 0.963 +/- 0.004
# iter   150 | train loss 0.139 acc 0.965 | val acc 0.976 +/- 0.003
# iter   200 | train loss 0.115 acc 0.969 | val acc 0.976 +/- 0.003
# iter   250 | train loss 0.089 acc 0.980 | val acc 0.979 +/- 0.003
# iter   300 | train loss 0.094 acc 0.981 | val acc 0.979 +/- 0.002
# TEST 5-way 5-shot: 98.23% +/- 0.14% (over 1000 episodes)

# %%
# !gcloud ai models list --region=us-central1 --project=dark-data-discovery \
  --filter='displayName=fsl-protonet-omniglot' --format='value(name)'
# Out:
# Using endpoint [https://us-central1-aiplatform.googleapis.com/]
# 8493947776650969088

# %%
# !gcloud ai models list-versions 8493947776650969088 --region=us-central1 --project=dark-data-discovery
# Out:
# ERROR: (gcloud.ai.models) Invalid choice: 'list-versions'.
# Maybe you meant:
#   gcloud ai model-garden
#   gcloud ai models
#   gcloud ai-platform models
#   gcloud ai-platform versions
#
# To search the help text of gcloud commands, run:
#   gcloud help -- SEARCH_TERMS
